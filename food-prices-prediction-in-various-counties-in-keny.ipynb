# %%
# !pip install catboost
# !pip install xgboost

# %% [markdown]
# # 1. Import Necessary Libraries

# %%
# import necessary libraries
import pandas as pd #library for data manipulation
import numpy as np # library for working with arrays

# import preprocessing libraries

# creating visualizations in Python
import matplotlib.pyplot as plt
import plotly.express as px
from pylab import rcParams
import seaborn as sns
sns.set_style('darkgrid')
rcParams['figure.figsize'] = 8,8
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# import modelling libraries
from catboost import CatBoostRegressor #features built in support for handling categorical features
from xgboost import XGBRegressor #designed to be fast and efficient: for both classification and regression
from sklearn.ensemble import RandomForestRegressor #creates multiple decision trees
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, RepeatedStratifiedKFold

# pd.options.display.max_rows=2000
pd.set_option('display.max_rows', 100) #sets maximum rows to 100
pd.set_option('display.max_columns', 30) #sets maximum columns to 30

# %% [markdown]
# # 2. Read Data

# %%
# read csv data
df = pd.read_csv('wfp_food_prices_ken.csv', parse_dates=True, index_col='date')

# %%
# check sample data/records
df.sample(5)
# Out:
#                  admin1   admin2                  market      latitude  \
# date
# 2021-01-15  Rift Valley  Baringo  Marigat town (Baringo)      0.469569
# 2006-09-15      Nairobi  Nairobi                 Nairobi     -1.283333
# 2021-04-15        Coast  Mombasa        Moroto (Mombasa)  -4.033844222
# 2018-02-15      Nairobi  Nairobi                 Nairobi     -1.283333
# 2021-01-15      Nairobi  Nairobi     Kitengela (Kajiado)     -1.285515
#
#               longitude               category           commodity   unit  \
# date
# 2021-01-15    35.980663     cereals and tubers  Maize (white, dry)  90 KG
# 2006-09-15    36.816667        pulses and nuts               Beans     KG
# 2021-04-15  39.65619357     cereals and tubers    Potatoes (Irish)     KG
# 2018-02-15    36.816667     cereals and tubers               Bread  400 G
# 2021-01-15      36.8556  vegetables and fruits       Cowpea leaves     KG
#
#             priceflag  pricetype currency   price usdprice
# date
# 2021-01-15     actual  Wholesale      KES  2430.0  22.2121
# 2006-09-15     actual  Wholesale      KES   34.75   0.4783
# 2021-04-15  aggregate     Retail      KES   56.18    0.531
# 2018-02-15     actual     Retail      KES    45.0   0.4514
# 2021-01-15     actual  Wholesale      KES    30.0   0.2742

# %% [markdown]
# # 3. Data Type description and statistical information

# %%
# check shape of the dataset
df.shape
# Out:
# (14755, 13)

# %%
# check information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# Index: 14755 entries, #date to 2022-08-15
#
# Data columns (total 13 columns):
#
#  #   Column     Non-Null Count  Dtype
#
# ---  ------     --------------  -----
#
#  0   admin1     14755 non-null  object
#
#  1   admin2     14755 non-null  object
#
#  2   market     14755 non-null  object
#
#  3   latitude   14755 non-null  object
#
#  4   longitude  14755 non-null  object
#
#  5   category   14755 non-null  object
#
#  6   commodity  14755 non-null  object
#
#  7   unit       14755 non-null  object
#
#  8   priceflag  14755 non-null  object
#
#  9   pricetype  14755 non-null  object
#
#  10  currency   14755 non-null  object
#
#  11  price      14755 non-null  object
#
#  12  usdprice   14755 non-null  object
#
# dtypes: object(13)
#
# memory usage: 1.6+ MB

# %% [markdown]
# ###
# * From the above, all columns are categorical. Shows there are anomalies since some
#   columns cant have object as a datatype i.e price etc.
# * No missing values from the dataset

# %%
# check statistical information of numerical data
# df.describe()

# %% [markdown]
# # 4. Data Preprocessing

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 251

# %%
# remove duplicates
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
# check for missing values and sorting the issue
missing_perc = df.isnull().mean()*100
missing_values = pd.DataFrame({'column_name' : df.columns, 'Missing Percentage' : missing_perc})
missing_values
# Out:
#           column_name  Missing Percentage
# admin1         admin1                 0.0
# admin2         admin2                 0.0
# market         market                 0.0
# latitude     latitude                 0.0
# longitude   longitude                 0.0
# category     category                 0.0
# commodity   commodity                 0.0
# unit             unit                 0.0
# priceflag   priceflag                 0.0
# pricetype   pricetype                 0.0
# currency     currency                 0.0
# price           price                 0.0
# usdprice     usdprice                 0.0

# %% [markdown]
# ###
# - No missing values from the dataset

# %%
# make a copy of the dataframe
df1 = df.copy()

# %%
# rename some columns
df1 = df1.rename(columns={'admin1': 'Province', 'admin2': 'County'})

# %%
# column names
print(*df1.columns, sep='\n')
# Out:
# Province
#
# County
#
# market
#
# latitude
#
# longitude
#
# category
#
# commodity
#
# unit
#
# priceflag
#
# pricetype
#
# currency
#
# price
#
# usdprice

# %%
# check datatypes of the above columns
for col in df1:
    print(f'{col} : {df1[col].dtypes}')
# Out:
# Province : object
#
# County : object
#
# market : object
#
# latitude : object
#
# longitude : object
#
# category : object
#
# commodity : object
#
# unit : object
#
# priceflag : object
#
# pricetype : object
#
# currency : object
#
# price : object
#
# usdprice : object

# %%
# remove some patterns in the cols you want to convert into numerical
num_cols = ['latitude', 'longitude', 'price', 'usdprice']
import re
def numeric(text):
    text = text.lower()
    if re.search(r'#', text):
        text = 0
    return text

df1[num_cols] = df1[num_cols].applymap(numeric)

# %%
# convert necessary columns to their respective datatypes
num_cols = ['latitude', 'longitude', 'price', 'usdprice']
for num in num_cols:
    df1[num] = df1[num].astype('float64')
    
df1.dtypes
# Out:
# Province      object
# County        object
# market        object
# latitude     float64
# longitude    float64
# category      object
# commodity     object
# unit          object
# priceflag     object
# pricetype     object
# currency      object
# price        float64
# usdprice     float64
# dtype: object

# %% [markdown]
# ###
# - I now have a clean dataset with their corresponding data types

# %%
# check statistical information of numerical data
df1.describe()
# Out:
#            latitude     longitude         price      usdprice
# count  14504.000000  14504.000000  14504.000000  14504.000000
# mean      -0.215473     36.901888   1934.812354     18.891459
# std        2.105010      1.840700   2865.725311     26.884711
# min       -4.659730      0.000000      0.000000      0.000000
# 25%       -1.283333     35.283333     53.360000      0.553675
# 50%       -0.303099     36.816667    184.120000      1.820700
# 75%        0.516667     37.989172   3000.000000     31.058300
# max        3.936804     41.858383  19800.000000    183.806900

# %% [markdown]
# ###
# - No outliers in my dataset

# %% [markdown]
# ### 4.1 Quality mapping

# %%
# columns
df1.columns
# Out:
# Index(['Province', 'County', 'market', 'latitude', 'longitude', 'category',
#        'commodity', 'unit', 'priceflag', 'pricetype', 'currency', 'price',
#        'usdprice'],
#       dtype='object')

# %%
# check category 
print(*df1['category'].unique(), sep='\n')
# Out:
# #item+type
#
# cereals and tubers
#
# pulses and nuts
#
# milk and dairy
#
# oil and fats
#
# non-food
#
# meat, fish and eggs
#
# miscellaneous food
#
# vegetables and fruits

# %% [markdown]
# ###
# - category seems to be ok

# %%
# check commodity 
print(*df1['commodity'].unique(), sep='\n')
# Out:
# #item+name
#
# Maize
#
# Maize (white)
#
# Beans
#
# Beans (dry)
#
# Potatoes (Irish)
#
# Sorghum
#
# Bread
#
# Milk (cow, pasteurized)
#
# Oil (vegetable)
#
# Fuel (diesel)
#
# Fuel (kerosene)
#
# Fuel (petrol-gasoline)
#
# Maize flour
#
# Rice
#
# Wheat flour
#
# Meat (beef)
#
# Meat (goat)
#
# Milk (UHT)
#
# Sugar
#
# Cooking fat
#
# Bananas
#
# Kale
#
# Onions (red)
#
# Tomatoes
#
# Potatoes (Irish, red)
#
# Beans (kidney)
#
# Beans (rosecoco)
#
# Beans (yellow)
#
# Cabbage
#
# Onions (dry)
#
# Spinach
#
# Potatoes (Irish, white)
#
# Rice (aromatic)
#
# Sorghum (red)
#
# Beans (dolichos)
#
# Cowpeas
#
# Cowpea leaves
#
# Maize (white, dry)
#
# Beans (mung)
#
# Millet (finger)
#
# Rice (imported, Pakistan)
#
# Fish (omena, dry)
#
# Sorghum (white)
#
# Salt
#
# Meat (camel)
#
# Milk (camel, fresh)
#
# Milk (cow, fresh)

# %%
# do a quality mapping on commodity column
import re
def commodity(text):
    text = text.lower()
    if re.match(r'^ma', text):
        text = 'Maize'
    if re.match(r'^b', text):
        text = 'Beans'
    if re.match(r'^p', text):
        text = 'Potatoes'
    if re.match(r'^mi', text):
        text = 'Milk'
    if re.match(r'^fu', text):
        text = 'Fuel'
    if re.match(r'^mea', text):
        text = 'Meat'
    if re.match(r'^oi', text):
        text = 'Oil'
    if re.match(r'^on', text):
        text = 'Onion'
    if re.match(r'^ri', text):
        text = 'Rice'
    if re.match(r'^so', text):
        text = 'Sorghum'
    if re.match(r'^cow', text):
        text = 'Cowpeas'
    if re.match(r'^mil', text):
        text = 'Millet'
    if re.match(r'^fis', text):
        text = 'Fish'
    return text
        
df1['commodity'] = df1['commodity'].apply(commodity)
print('Unique values in Commodity column: ')
print('-------------------------------')
print(*df1['commodity'].unique(), sep='\n')
print('-------------------------------')
# Out:
# Unique values in Commodity column:
#
# -------------------------------
#
# #item+name
#
# Maize
#
# Beans
#
# Potatoes
#
# Sorghum
#
# Milk
#
# Oil
#
# Fuel
#
# Rice
#
# wheat flour
#
# Meat
#
# sugar
#
# cooking fat
#
# kale
#
# Onion
#
# tomatoes
#
# cabbage
#
# spinach
#
# Cowpeas
#
# Fish
#
# salt
#
# -------------------------------

# %%
# check unit column 
print(*df1['unit'].unique(), sep='\n')
# Out:
# #item+unit
#
# KG
#
# 90 KG
#
# 50 KG
#
# 400 G
#
# 500 ML
#
# L
#
# 200 ML
#
# Unit
#
# Bunch
#
# 126 KG
#
# 13 KG
#
# 64 KG
#
# 200 G
#
# Head

# %%
# do a quality mapping on unit column
import re
def unit(text):
    text = text.lower()
    if text == 'bunch' or text == 'head':
        return text
    text = re.sub(r'(\d+\s*kg|\d+\s*g)', '1 KG', text)
    text = re.sub(r'(\d+\s*ml|\d+\s*l)', '1 L', text)
    text = re.sub(r'(?<!\d)l(?!\w)', '1 L', text)
    return text



df1['unit'] = df1['unit'].apply(unit)
print('Unique values in Unit column: ')
print('-------------------------------')
print(*df1['unit'].unique(), sep='\n')
print('-------------------------------')
# Out:
# Unique values in Unit column:
#
# -------------------------------
#
# #item+unit
#
# kg
#
# 1 KG
#
# 1 L
#
# unit
#
# bunch
#
# head
#
# -------------------------------

# %%
# df1.columns

# %%
# confirm unique values of our columns
excluded_cols = ['Province', 'County', 'market', 'price', 'usdprice', 'latitude', 'longitude']
for col in df1.columns:
    if col not in excluded_cols:
        unique_values = "\n".join(df1[col].unique().astype(str))
        print(f'{col} : {df1[col].nunique()} : {unique_values}\n')
        print('------------------------------------------')
# Out:
# category : 9 : #item+type
#
# cereals and tubers
#
# pulses and nuts
#
# milk and dairy
#
# oil and fats
#
# non-food
#
# meat, fish and eggs
#
# miscellaneous food
#
# vegetables and fruits
#
#
#
# ------------------------------------------
#
# commodity : 21 : #item+name
#
# Maize
#
# Beans
#
# Potatoes
#
# Sorghum
#
# Milk
#
# Oil
#
# Fuel
#
# Rice
#
# wheat flour
#
# Meat
#
# sugar
#
# cooking fat
#
# kale
#
# Onion
#
# tomatoes
#
# cabbage
#
# spinach
#
# Cowpeas
#
# Fish
#
# salt
#
#
#
# ------------------------------------------
#
# unit : 7 : #item+unit
#
# kg
#
# 1 KG
#
# 1 L
#
# unit
#
# bunch
#
# head
#
#
#
# ------------------------------------------
#
# priceflag : 4 : #item+price+flag
#
# actual
#
# aggregate
#
# forecast
#
#
#
# ------------------------------------------
#
# pricetype : 3 : #item+price+type
#
# Wholesale
#
# Retail
#
#
#
# ------------------------------------------
#
# currency : 2 : #currency
#
# KES
#
#
#
# ------------------------------------------

# %%
# df1.dtypes

# %% [markdown]
# # 5. Feature Engineering
# - Here we will pick our essential features for training the model

# %%
# let us see our columns
df1.columns
# Out:
# Index(['Province', 'County', 'market', 'latitude', 'longitude', 'category',
#        'commodity', 'unit', 'priceflag', 'pricetype', 'currency', 'price',
#        'usdprice'],
#       dtype='object')

# %%
# create a copy of the df1 column
df2 = df1.copy()

# %%
# drop unnecessary columns
df2.drop(columns=['usdprice', 'currency'], axis=1, inplace=True)

# %%
# new columns to fit our model with
df2.columns
# Out:
# Index(['Province', 'County', 'market', 'latitude', 'longitude', 'category',
#        'commodity', 'unit', 'priceflag', 'pricetype', 'price'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# Province      object
# County        object
# market        object
# latitude     float64
# longitude    float64
# category      object
# commodity     object
# unit          object
# priceflag     object
# pricetype     object
# price        float64
# dtype: object

# %%
# encode the choosen columns
from sklearn.preprocessing import LabelEncoder

cat_cols = [column for column in df2.columns if df2[column].dtype == 'object']

# binary cols are the columns with only two unique values
binary_cols = [column for column in cat_cols if df2[column].nunique() == 3]
print(*binary_cols)
# Out:
# pricetype

# %%
df2 = pd.get_dummies(df2, columns=binary_cols, drop_first=True)
dummied_cols = [column for column in df2.columns if column not in cat_cols and column not in binary_cols]
df2.head()
# Out:
#               Province      County            market  latitude  longitude  \
# date
# #date       #adm1+name  #adm2+name  #loc+market+name      0.00   0.000000
# 2006-01-15       Coast     Mombasa           Mombasa     -4.05  39.666667
# 2006-01-15       Coast     Mombasa           Mombasa     -4.05  39.666667
# 2006-01-15       Coast     Mombasa           Mombasa     -4.05  39.666667
# 2006-01-15       Coast     Mombasa           Mombasa     -4.05  39.666667
#
#                       category   commodity        unit         priceflag  \
# date
# #date               #item+type  #item+name  #item+unit  #item+price+flag
# 2006-01-15  cereals and tubers       Maize          kg            actual
# 2006-01-15  cereals and tubers       Maize        1 KG            actual
# 2006-01-15     pulses and nuts       Beans          kg            actual
# 2006-01-15     pulses and nuts       Beans        1 KG            actual
#
#               price  pricetype_Retail  pricetype_Wholesale
# date
# #date          0.00                 0                    0
# 2006-01-15    16.13                 0                    1
# 2006-01-15  1480.00                 0                    1
# 2006-01-15    33.63                 0                    1
# 2006-01-15  3246.00                 0                    1

# %%
# Encode the categorical variables to numeric values
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

cat_cols = [column for column in df2.columns if df2[column].dtype == 'object']

# label encode the categorical columns
for column in cat_cols:
    df2[column] = le.fit_transform(df2[column])

df2.head()
# Out:
#             Province  County  market  latitude  longitude  category  \
# date
# #date              0       0       0      0.00   0.000000         0
# 2006-01-15         2      14      50     -4.05  39.666667         1
# 2006-01-15         2      14      50     -4.05  39.666667         1
# 2006-01-15         2      14      50     -4.05  39.666667         7
# 2006-01-15         2      14      50     -4.05  39.666667         7
#
#             commodity  unit  priceflag    price  pricetype_Retail  \
# date
# #date               0     0          0     0.00                 0
# 2006-01-15          5     5          1    16.13                 0
# 2006-01-15          5     1          1  1480.00                 0
# 2006-01-15          1     5          1    33.63                 0
# 2006-01-15          1     1          1  3246.00                 0
#
#             pricetype_Wholesale
# date
# #date                         0
# 2006-01-15                    1
# 2006-01-15                    1
# 2006-01-15                    1
# 2006-01-15                    1

# %%
# split into train and test split
X = df2.drop('price', axis=1)
y = df2['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11603, 11), (2901, 11), (11603,), (2901,))

# %%
# Initialize the model
from sklearn.metrics import r2_score
cat = CatBoostRegressor(loss_function='RMSE', n_estimators=100, learning_rate=0.05, max_depth=5)
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.05, max_depth=5)
linear = LinearRegression()
rf = RandomForestRegressor()
models= [cat,linear, rf,xgb]

# Fit the model to the training data
for model in models:
    model = model.fit(X_train, y_train)
    
    # Make predictions on the test data
    y_pred = model.predict(X_test)
    
    #metric
    mse = r2_score(y_test, y_pred) * 100
    print(f'error for {model} is: {mse}')
# Out:
# 0:	learn: 2745.3808962	total: 3.32ms	remaining: 329ms
#
# 1:	learn: 2638.8287645	total: 6ms	remaining: 294ms
#
# 2:	learn: 2538.7706867	total: 7.97ms	remaining: 258ms
#
# 3:	learn: 2449.1309117	total: 10.4ms	remaining: 249ms
#
# 4:	learn: 2363.8934738	total: 12.6ms	remaining: 239ms
#
# 5:	learn: 2284.8601480	total: 14.5ms	remaining: 228ms
#
# 6:	learn: 2211.9475751	total: 16.3ms	remaining: 217ms
#
# 7:	learn: 2142.2277855	total: 18.4ms	remaining: 212ms
#
# 8:	learn: 2073.5772624	total: 20.1ms	remaining: 203ms
#
# 9:	learn: 2010.5891108	total: 22ms	remaining: 198ms
#
# 10:	learn: 1954.2749022	total: 23.2ms	remaining: 188ms
#
# 11:	learn: 1898.1363973	total: 25ms	remaining: 183ms
#
# 12:	learn: 1845.4823356	total: 26.9ms	remaining: 180ms
#
# 13:	learn: 1799.0337097	total: 28.8ms	remaining: 177ms
#
# 14:	learn: 1756.8080484	total: 30.2ms	remaining: 171ms
#
# 15:	learn: 1713.6163492	total: 31.7ms	remaining: 166ms
#
# 16:	learn: 1674.2762593	total: 33.5ms	remaining: 163ms
#
# 17:	learn: 1636.1482103	total: 35.1ms	remaining: 160ms
#
# 18:	learn: 1605.1707920	total: 36.6ms	remaining: 156ms
#
# 19:	learn: 1572.5915879	total: 38.1ms	remaining: 152ms
#
# 20:	learn: 1542.7889662	total: 40ms	remaining: 150ms
#
# 21:	learn: 1516.5158711	total: 41.3ms	remaining: 146ms
#
# 22:	learn: 1490.1951074	total: 43.5ms	remaining: 146ms
#
# 23:	learn: 1462.8875238	total: 44.9ms	remaining: 142ms
#
# 24:	learn: 1440.6096869	total: 46.2ms	remaining: 139ms
#
# 25:	learn: 1420.1478575	total: 47.6ms	remaining: 136ms
#
# 26:	learn: 1402.5168166	total: 49.1ms	remaining: 133ms
#
# 27:	learn: 1381.1808235	total: 50.5ms	remaining: 130ms
#
# 28:	learn: 1365.2351096	total: 52ms	remaining: 127ms
#
# 29:	learn: 1348.6565831	total: 53.4ms	remaining: 125ms
#
# 30:	learn: 1332.8513669	total: 54.9ms	remaining: 122ms
#
# 31:	learn: 1317.1288066	total: 56.4ms	remaining: 120ms
#
# 32:	learn: 1306.2307253	total: 58.1ms	remaining: 118ms
#
# 33:	learn: 1294.0644128	total: 59.7ms	remaining: 116ms
#
# 34:	learn: 1283.7960375	total: 61.2ms	remaining: 114ms
#
# 35:	learn: 1271.9169402	total: 62.6ms	remaining: 111ms
#
# 36:	learn: 1262.1205790	total: 64ms	remaining: 109ms
#
# 37:	learn: 1252.8958193	total: 65.9ms	remaining: 108ms
#
# 38:	learn: 1241.6094850	total: 67.7ms	remaining: 106ms
#
# 39:	learn: 1235.0616687	total: 69.3ms	remaining: 104ms
#
# 40:	learn: 1226.2076887	total: 70.8ms	remaining: 102ms
#
# 41:	learn: 1217.0275415	total: 72.3ms	remaining: 99.8ms
#
# 42:	learn: 1209.8691070	total: 73.9ms	remaining: 98ms
#
# 43:	learn: 1202.6604332	total: 76ms	remaining: 96.7ms
#
# 44:	learn: 1197.3454989	total: 77.4ms	remaining: 94.7ms
#
# 45:	learn: 1189.9310261	total: 78.9ms	remaining: 92.6ms
#
# 46:	learn: 1185.1902954	total: 80.3ms	remaining: 90.6ms
#
# 47:	learn: 1180.1899076	total: 81.7ms	remaining: 88.5ms
#
# 48:	learn: 1175.1338678	total: 83.2ms	remaining: 86.6ms
#
# 49:	learn: 1168.8270727	total: 85ms	remaining: 85ms
#
# 50:	learn: 1163.3529727	total: 86.6ms	remaining: 83.2ms
#
# 51:	learn: 1159.1561944	total: 88ms	remaining: 81.3ms
#
# 52:	learn: 1154.2033349	total: 89.5ms	remaining: 79.3ms
#
# 53:	learn: 1147.9096338	total: 90.9ms	remaining: 77.5ms
#
# 54:	learn: 1144.5019182	total: 92.6ms	remaining: 75.8ms
#
# 55:	learn: 1139.5816405	total: 94.1ms	remaining: 74ms
#
# 56:	learn: 1135.4395753	total: 95.6ms	remaining: 72.1ms
#
# 57:	learn: 1132.6985710	total: 97.2ms	remaining: 70.4ms
#
# 58:	learn: 1129.2828507	total: 98.6ms	remaining: 68.5ms
#
# 59:	learn: 1124.8727435	total: 100ms	remaining: 66.7ms
#
# 60:	learn: 1120.8286723	total: 101ms	remaining: 64.8ms
#
# 61:	learn: 1118.9080839	total: 103ms	remaining: 63ms
#
# 62:	learn: 1115.0034568	total: 104ms	remaining: 61.2ms
#
# 63:	learn: 1111.8245029	total: 106ms	remaining: 59.4ms
#
# 64:	learn: 1108.4497309	total: 107ms	remaining: 57.7ms
#
# 65:	learn: 1105.7723647	total: 109ms	remaining: 55.9ms
#
# 66:	learn: 1103.6330702	total: 110ms	remaining: 54.1ms
#
# 67:	learn: 1101.1443201	total: 111ms	remaining: 52.4ms
#
# 68:	learn: 1098.3615329	total: 113ms	remaining: 50.7ms
#
# 69:	learn: 1095.9274873	total: 114ms	remaining: 49ms
#
# 70:	learn: 1093.4427372	total: 116ms	remaining: 47.3ms
#
# 71:	learn: 1091.2162194	total: 117ms	remaining: 45.6ms
#
# 72:	learn: 1088.7588354	total: 119ms	remaining: 43.9ms
#
# 73:	learn: 1086.2920765	total: 120ms	remaining: 42.3ms
#
# 74:	learn: 1084.6845528	total: 122ms	remaining: 40.7ms
#
# 75:	learn: 1082.4325969	total: 123ms	remaining: 38.9ms
#
# 76:	learn: 1081.0332000	total: 125ms	remaining: 37.2ms
#
# 77:	learn: 1077.7225766	total: 126ms	remaining: 35.5ms
#
# 78:	learn: 1075.6723413	total: 127ms	remaining: 33.9ms
#
# 79:	learn: 1073.7652397	total: 129ms	remaining: 32.2ms
#
# 80:	learn: 1070.8067265	total: 130ms	remaining: 30.6ms
#
# 81:	learn: 1068.7745884	total: 132ms	remaining: 28.9ms
#
# 82:	learn: 1066.8303621	total: 133ms	remaining: 27.3ms
#
# 83:	learn: 1065.7974568	total: 135ms	remaining: 25.6ms
#
# 84:	learn: 1063.7283401	total: 136ms	remaining: 24ms
#
# 85:	learn: 1062.3933535	total: 137ms	remaining: 22.3ms
#
# 86:	learn: 1061.0186827	total: 139ms	remaining: 20.7ms
#
# 87:	learn: 1058.6105245	total: 140ms	remaining: 19.1ms
#
# 88:	learn: 1057.5653376	total: 142ms	remaining: 17.5ms
#
# 89:	learn: 1056.1459024	total: 143ms	remaining: 15.9ms
#
# 90:	learn: 1054.7155987	total: 145ms	remaining: 14.3ms
#
# 91:	learn: 1053.3095598	total: 146ms	remaining: 12.7ms
#
# 92:	learn: 1052.0936579	total: 147ms	remaining: 11.1ms
#
# 93:	learn: 1050.8554000	total: 149ms	remaining: 9.5ms
#
# 94:	learn: 1048.6019040	total: 150ms	remaining: 7.92ms
#
# 95:	learn: 1047.8993059	total: 152ms	remaining: 6.32ms
#
# 96:	learn: 1046.4887469	total: 153ms	remaining: 4.73ms
#
# 97:	learn: 1044.7374611	total: 154ms	remaining: 3.15ms
#
# 98:	learn: 1043.6337788	total: 156ms	remaining: 1.57ms
#
# 99:	learn: 1042.7364662	total: 157ms	remaining: 0us
#
# error for <catboost.core.CatBoostRegressor object at 0x7f3b11fabcd0> is: 85.8320917326567
#
# error for LinearRegression() is: 51.85084046119803
#
# error for RandomForestRegressor() is: 88.46623360750179
#
# error for XGBRegressor(base_score=None, booster=None, callbacks=None,
#
#              colsample_bylevel=None, colsample_bynode=None,
#
#              colsample_bytree=None, early_stopping_rounds=None,
#
#              enable_categorical=False, eval_metric=None, feature_types=None,
#
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#
#              max_cat_threshold=None, max_cat_to_onehot=None,
#
#              max_delta_step=None, max_depth=5, max_leaves=None,
#
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#
#              predictor=None, random_state=None, ...) is: 87.70601038785318

# %% [markdown]
# # CONCLUSION!
# - From the trained models above,.. RandomForestRegressor, XGBRegressor and CatBoostRegressor are doing exemplary good. RandomForestRegressor tends to be best... tuning both XGBRegressor and CatBoostRegressor can be good

# %%
# testing random forest with random data
rf = RandomForestRegressor()
rf = rf.fit(X_train, y_train)
rf
# Out:
# RandomForestRegressor()

# %%
# df.head()

# %%
df2.head()
# Out:
#             Province  County  market  latitude  longitude  category  \
# date
# #date              0       0       0      0.00   0.000000         0
# 2006-01-15         2      14      50     -4.05  39.666667         1
# 2006-01-15         2      14      50     -4.05  39.666667         1
# 2006-01-15         2      14      50     -4.05  39.666667         7
# 2006-01-15         2      14      50     -4.05  39.666667         7
#
#             commodity  unit  priceflag    price  pricetype_Retail  \
# date
# #date               0     0          0     0.00                 0
# 2006-01-15          5     5          1    16.13                 0
# 2006-01-15          5     1          1  1480.00                 0
# 2006-01-15          1     5          1    33.63                 0
# 2006-01-15          1     1          1  3246.00                 0
#
#             pricetype_Wholesale
# date
# #date                         0
# 2006-01-15                    1
# 2006-01-15                    1
# 2006-01-15                    1
# 2006-01-15                    1
